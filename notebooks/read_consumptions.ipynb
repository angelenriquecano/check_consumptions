# %%
import os
import pandas as pd
import plotly.graph_objects as go
import datetime as dt

# %%
dataDir = os.path.join(os.getcwd(), 'data')
print(os.listdir(dataDir))
# Out:
# ['Potencias_5543701-06-2024_10-10-2024.csv', 'Consumo_5555301-01-2024_14-10-2024.csv', 'Consumo_5540301-01-2024_10-10-2024.csv']

# %%
_DF = []

df = pd.read_csv(
    os.path.join(dataDir, os.listdir(dataDir)[2]),
    header=0,
    sep=';',
    decimal=','
)
df
# Out:
#                         cups       fecha   hora  consumo_kWh metodoObtencion  \
# 0     ES0022000005635208CB1P  2024/01/01  01:00        0.516            Real
# 1     ES0022000005635208CB1P  2024/01/01  02:00        1.448            Real
# 2     ES0022000005635208CB1P  2024/01/01  03:00        0.670            Real
# 3     ES0022000005635208CB1P  2024/01/01  04:00        0.103            Real
# 4     ES0022000005635208CB1P  2024/01/01  05:00        0.216            Real
# ...                      ...         ...    ...          ...             ...
# 6762  ES0022000005635208CB1P  2024/10/08  20:00        0.684            Real
# 6763  ES0022000005635208CB1P  2024/10/08  21:00        1.784            Real
# 6764  ES0022000005635208CB1P  2024/10/08  22:00        1.190            Real
# 6765  ES0022000005635208CB1P  2024/10/08  23:00        0.302            Real
# 6766  ES0022000005635208CB1P  2024/10/08  24:00        0.211            Real
#
#       energiaVertida_kWh
# ...

# %%
def fecha_hora_to_datetime(x):
    _str_hora = int(x['hora'].split(':')[0])
    return dt.datetime.strptime(f"{x['fecha']}-{_str_hora-1}:00", "%Y/%m/%d-%H:%M")

# %%
df['Timestamp'] = df.apply(fecha_hora_to_datetime, axis=1)
df = df.set_index('Timestamp')
df['Pot_Contratada'] = 3.45
df
# Out:
#                                        cups       fecha   hora  consumo_kWh  \
# Timestamp
# 2024-01-01 00:00:00  ES0022000005635208CB1P  2024/01/01  01:00        0.516
# 2024-01-01 01:00:00  ES0022000005635208CB1P  2024/01/01  02:00        1.448
# 2024-01-01 02:00:00  ES0022000005635208CB1P  2024/01/01  03:00        0.670
# 2024-01-01 03:00:00  ES0022000005635208CB1P  2024/01/01  04:00        0.103
# 2024-01-01 04:00:00  ES0022000005635208CB1P  2024/01/01  05:00        0.216
# ...                                     ...         ...    ...          ...
# 2024-10-08 19:00:00  ES0022000005635208CB1P  2024/10/08  20:00        0.684
# 2024-10-08 20:00:00  ES0022000005635208CB1P  2024/10/08  21:00        1.784
# 2024-10-08 21:00:00  ES0022000005635208CB1P  2024/10/08  22:00        1.190
# 2024-10-08 22:00:00  ES0022000005635208CB1P  2024/10/08  23:00        0.302
# 2024-10-08 23:00:00  ES0022000005635208CB1P  2024/10/08  24:00        0.211
#
# ...

# %%
import numpy as np
fig = go.Figure()
fig.add_traces(
    [
        go.Scatter(
            x = df.index,
            y = df.consumo_kWh,
            name='Consumo'               
        ),
        go.Scatter(
            x = df.index,
            y = df.Pot_Contratada,
            name='Energ_Max_Horaria = Pot_Contratada'               
        ),
        go.Bar(
            x = df.loc[df['metodoObtencion'] == 'Estimada'].index,
            y = df.loc[df['metodoObtencion'] == 'Estimada'].consumo_kWh.max() * np.ones(len(df.loc[df['metodoObtencion'] == 'Estimada'].index)),
            name='Estimadas',
            marker_color='rgb(255, 87, 51)', 
            marker_line_color='rgb(8,48,107)',
            marker_line_width=1.5, 
            opacity=0.3

        )
    ]
    
)
fig.update_layout(
    title='Consumo desde Enero 2024 hasta Octube 2024'
)
fig.show()

# %%
dataDir = os.path.join(os.getcwd(), 'data')
print(os.listdir(dataDir))
# Out:
# ['Potencias_5543701-06-2024_10-10-2024.csv', 'Consumo_5803801-01-2024_11-11-2024.csv', 'Consumo_5555301-01-2024_14-10-2024.csv', 'Consumo_5540301-01-2024_10-10-2024.csv', 'Potencias_5803901-01-2024_11-11-2024.csv']

# %%
_DF = []

df = pd.read_csv(
    os.path.join(dataDir, os.listdir(dataDir)[1]),
    header=0,
    sep=';',
    decimal=','
)
df
# Out:
#                         cups       fecha   hora  consumo_kWh metodoObtencion  \
# 0     ES0022000005635208CB1P  2024/01/01  01:00        0.516            Real
# 1     ES0022000005635208CB1P  2024/01/01  02:00        1.448            Real
# 2     ES0022000005635208CB1P  2024/01/01  03:00        0.670            Real
# 3     ES0022000005635208CB1P  2024/01/01  04:00        0.103            Real
# 4     ES0022000005635208CB1P  2024/01/01  05:00        0.216            Real
# ...                      ...         ...    ...          ...             ...
# 7531  ES0022000005635208CB1P  2024/11/09  20:00        0.784            Real
# 7532  ES0022000005635208CB1P  2024/11/09  21:00        0.358            Real
# 7533  ES0022000005635208CB1P  2024/11/09  22:00        0.240            Real
# 7534  ES0022000005635208CB1P  2024/11/09  23:00        0.203            Real
# 7535  ES0022000005635208CB1P  2024/11/09  24:00        0.139            Real
#
#       energiaVertida_kWh
# ...

# %%
def fecha_hora_to_datetime(x):
    _str_hora = int(x['hora'].split(':')[0])
    return dt.datetime.strptime(f"{x['fecha']}-{_str_hora-1}:00", "%Y/%m/%d-%H:%M")

# %%
df['Timestamp'] = df.apply(fecha_hora_to_datetime, axis=1)
df = df.set_index('Timestamp')
df['Pot_Contratada'] = 3.45
df
# Out:
#                                        cups       fecha   hora  consumo_kWh  \
# Timestamp
# 2024-01-01 00:00:00  ES0022000005635208CB1P  2024/01/01  01:00        0.516
# 2024-01-01 01:00:00  ES0022000005635208CB1P  2024/01/01  02:00        1.448
# 2024-01-01 02:00:00  ES0022000005635208CB1P  2024/01/01  03:00        0.670
# 2024-01-01 03:00:00  ES0022000005635208CB1P  2024/01/01  04:00        0.103
# 2024-01-01 04:00:00  ES0022000005635208CB1P  2024/01/01  05:00        0.216
# ...                                     ...         ...    ...          ...
# 2024-11-09 19:00:00  ES0022000005635208CB1P  2024/11/09  20:00        0.784
# 2024-11-09 20:00:00  ES0022000005635208CB1P  2024/11/09  21:00        0.358
# 2024-11-09 21:00:00  ES0022000005635208CB1P  2024/11/09  22:00        0.240
# 2024-11-09 22:00:00  ES0022000005635208CB1P  2024/11/09  23:00        0.203
# 2024-11-09 23:00:00  ES0022000005635208CB1P  2024/11/09  24:00        0.139
#
# ...

# %%
import numpy as np
fig = go.Figure()
fig.add_traces(
    [
        go.Scatter(
            x = df.index,
            y = df.consumo_kWh,
            name='Consumo'               
        ),
        go.Scatter(
            x = df.index,
            y = df.Pot_Contratada,
            name='Energ_Max_Horaria = Pot_Contratada'               
        ),
        go.Bar(
            x = df.loc[df['metodoObtencion'] == 'Estimada'].index,
            y = df.loc[df['metodoObtencion'] == 'Estimada'].consumo_kWh.max() * np.ones(len(df.loc[df['metodoObtencion'] == 'Estimada'].index)),
            name='Estimadas',
            marker_color='rgb(255, 87, 51)', 
            marker_line_color='rgb(8,48,107)',
            marker_line_width=1.5, 
            opacity=0.3

        )
    ]
    
)
fig.update_layout(
    title='Consumo desde Enero 2024 hasta Octube 2024'
)
fig.show()
